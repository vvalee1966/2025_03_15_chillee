# %% [markdown]
# <a href="https://colab.research.google.com/github/vvalee1966/2025_03_15_chillee/blob/main/test/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 這裡是一個建立'正弦波'的圖表範例

# %%
import numpy as np
import matplotlib.pyplot as plt

# 產生 x 軸數據
x = np.linspace(0, 2 * np.pi, 100)

# 計算正弦波 y 軸數據
y = np.sin(x)

# 繪製圖表
plt.plot(x, y)

# 設定圖表標題和軸標籤
plt.title('sin')
plt.xlabel('x 軸')
plt.ylabel('y 軸')

# 顯示圖表
plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36600 (\N{CJK UNIFIED IDEOGRAPH-8EF8}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 建立 x 軸資料點，從 0 到 2π，共 100 個點
x = np.linspace(0, 2 * np.pi, 100)

# 計算每個 x 值的 sin 值
y = np.sin(x)

# 使用 matplotlib 繪製圖表
plt.plot(x, y)
plt.xlabel("x")  # 設定 x 軸標籤
plt.ylabel("sin(x)")  # 設定 y 軸標籤
plt.title("sin splot")  # 設定圖表標題
plt.grid(True)  # 顯示格線
plt.show()  # 顯示圖表

# %% [markdown]
# 同時顯示sin的正弦圖表
