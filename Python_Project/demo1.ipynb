# %% [markdown]
# <a href="https://colab.research.google.com/github/vvalee1966/2025_03_15_chillee/blob/main/Python_Project/demo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 建立`正弦波`圖表範例

# %%
import numpy as np
import matplotlib.pyplot as plt

# 建立 x 軸數據，從 0 到 2π，間隔為 0.1
x = np.arange(0, 2*np.pi, 0.1)

# 計算 y 軸數據，使用 sin() 函數
y = np.sin(x)

# 使用 matplotlib 繪製圖表
plt.plot(x, y)  # 繪製 x 和 y 的關係圖，形成正弦波圖表

# 設定圖表標題和軸標籤
plt.title('sin plot')  # 設定圖表標題
plt.xlabel('x (弧度)')  # 設定 x 軸標籤
plt.ylabel('sin(x)')  # 設定 y 軸標籤

# 顯示圖表
plt.show()  # 顯示繪製好的圖表

# %% [markdown]
# - 建立`餘弦波`圖表範例

# %%
import numpy as np
import matplotlib.pyplot as plt

# 建立 x 軸數據，從 0 到 2π，間隔為 0.1
x = np.arange(0, 2*np.pi, 0.1)

# 計算 y 軸數據，使用 cos() 函數
y = np.cos(x)

# 使用 matplotlib 繪製圖表
plt.plot(x, y)  # 繪製 x 和 y 的關係圖，形成餘弦波圖表

# 設定圖表標題和軸標籤
plt.title('cos plot')  # 設定圖表標題
plt.xlabel('x (弧度)')  # 設定 x 軸標籤
plt.ylabel('cos(x)')  # 設定 y 軸標籤

# 顯示圖表
plt.show()  # 顯示繪製好的圖表
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24359 (\N{CJK UNIFIED IDEOGRAPH-5F27}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
